# %% [markdown]
# # Dance Worlds Data Cleaning

# %%
import pandas as pd
import re
import pandas as pd
import re
from difflib import SequenceMatcher

# %%
# Load the CSV file
df = pd.read_csv('dance_worlds_data_20251004_221418.csv')

# %%
# Display basic info about the dataset
print("Dataset Info:")
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")
print(f"\nColumn names: {list(df.columns)}")
# Out:
# Dataset Info:
# Total rows: 1953
# Total columns: 12
#
# Column names: ['Year', 'Rank', 'Category', 'Studio_Name', 'Team_Name', 'Country', 'Dance_Type', 'Category_Clean', 'Category_Standardized', 'Division', 'Studio_Name_Clean', 'Team_Name_Clean']

# %%
# List all unique values in Dance_Type
unique_dance_types = df['Dance_Type'].unique()
print(f"Total unique dance types: {len(unique_dance_types)}")
print("\nDance Types:")
for dance_type in sorted(unique_dance_types):
    count = len(df[df['Dance_Type'] == dance_type])
    print(f"  {dance_type}: {count} records")
# Out:
# Total unique dance types: 6
#
# Dance Types:
#   Contemporary/Lyrical: 254 records
#   Hip Hop: 646 records
#   Jazz: 405 records
#   Junior Dance: 139 records
#   Kick: 26 records
#   Pom: 483 records

# %%
# List all unique values in Category
unique_categories = df['Category'].unique()
print(f"Total unique categories: {len(unique_categories)}")
print("\nCategories:")
for category in sorted(unique_categories):
    count = len(df[df['Category'] == category])
    print(f"  {category}: {count} records")
# Out:
# Total unique categories: 68
#
# Categories:
#   International Junior  Dance: 41 records
#   International Open  Contemporary/Lyrical: 22 records
#   International Open  Hip Hop: 54 records
#   International Open  Jazz: 49 records
#   International Open  Pom: 88 records
#   International Open Coed Hip Hop: 55 records
#   International Open Coed Jazz: 37 records
#   International Open Coed Pom: 36 records
#   International Open Male Hip Hop: 19 records
#   Junior  Dance: 31 records
#   Junior Dance: 67 records
#   Open  Contemporary/Lyrical: 16 records
#   Open  Jazz: 16 records
#   Open  Kick: 4 records
#   Open  Pom: 29 records
#   Open Coed Elite Hip Hop: 39 records
#   Open Coed Hip Hop: 17 records
#   Open Coed Jazz: 49 records
#   Open Coed Pom: 45 records
#   Open Coed Premier Hip Hop: 28 records
#   Open Contemporary/Lyrical: 16 records
#   Open Elite  Hip Hop: 10 records
#   Open Elite Coed Hip Hop: 12 records
#   Open Elite Contemporary/Lyrical: 14 records
#   Open Elite Hip Hop: 40 records
#   Open Elite Jazz: 12 records
#   Open Elite Pom: 16 records
#   Open Hip Hop: 14 records
#   Open Jazz: 47 records
#   Open Kick: 10 records
#   Open Male Hip Hop: 20 records
#   Open Open (Contemporary/Lyrical): 33 records
#   Open Pom: 75 records
#   Open Premier  Hip Hop: 8 records
#   Open Premier Coed Hip Hop: 12 records
#   Open Premier Contemporary/Lyrical: 7 records
#   Open Premier Hip Hop: 23 records
#   Open Premier Jazz: 4 records
#   Open Premier Pom: 11 records
#   Senior  Contemporary/Lyrical: 24 records
#   Senior  Contemporary/Lyrical Large: 8 records
#   Senior  Contemporary/Lyrical Small: 13 records
#   Senior  Hip Hop Large: 34 records
#   Senior  Hip Hop Small: 58 records
#   Senior  Jazz: 10 records
#   Senior  Jazz Large: 23 records
#   Senior  Jazz Small: 55 records
#   Senior  Pom: 10 records
#   Senior  Pom Large: 25 records
#   Senior  Pom Small: 47 records
#   Senior Coed Hip Hop Large: 25 records
#   Senior Coed Hip Hop Small: 36 records
#   Senior Jazz Large: 23 records
#   Senior Kick: 12 records
#   Senior Large Coed Hip Hop: 14 records
#   Senior Large Contemporary Lyrical: 20 records
#   Senior Large Contemporary/Lyrical: 13 records
#   Senior Large Hip Hop: 37 records
#   Senior Large Jazz: 17 records
#   Senior Large Pom: 35 records
#   Senior Small Coed Hip Hop: 19 records
#   Senior Small Contemporary Lyrical: 43 records
#   Senior Small Contemporary/Lyrical: 25 records
#   Senior Small Hip Hop: 61 records
#   Senior Small Jazz: 63 records
#   Senior Small Pom: 66 records
#   Small Large Coed Hip Hop: 5 records
#   Small Senior Coed Hip Hop: 6 records

# %%
# List all unique values in Country
unique_countries = df['Country'].unique()
print(f"Total unique countries: {len(unique_countries)}")
print("\nCountries:")
for country in sorted(unique_countries):
    count = len(df[df['Country'] == country])
    print(f"  {country}: {count} records")
# Out:
# Total unique countries: 25
#
# Countries:
#   Australia: 50 records
#   Canada: 8 records
#   Chile: 23 records
#   Colombia: 41 records
#   Ecuador: 40 records
#   England: 84 records
#   France: 14 records
#   Germany: 8 records
#   Italy: 2 records
#   Japan: 64 records
#   Mexico: 76 records
#   Monaco: 2 records
#   Netherlands: 6 records
#   New Zealand: 1 records
#   Philippines: 1 records
#   Poland: 3 records
#   Puerto Rico: 11 records
#   Russia: 1 records
#   Scotland: 69 records
#   Sweden: 3 records
#   Taiwan: 1 records
#   USA: 1181 records
#   Ukraine: 8 records
#   Unknown: 236 records
#   Wales: 20 records

# %%
# Display first few rows of the dataset
print(df.head())
# Out:
#    Year  Rank                     Category              Studio_Name  \
# 0  2015     1  International Junior  Dance     Dancer's Edge Studio
# 1  2016     1  International Junior  Dance     Dancer's Edge Studio
# 2  2017     1  International Junior  Dance     Dancer's Edge Studio
# 3  2015     2  International Junior  Dance                   C*Star
# 4  2016     2  International Junior  Dance  The Vision Dance Center
#
#                               Team_Name Country    Dance_Type  \
# 0                         Dancer's Edge     USA  Junior Dance
# 1                  Dancer's Edge Studio     USA  Junior Dance
# 2  Dancer's Edge Studio- Junior Lyrical     USA  Junior Dance
# 3                          C*Star Artis   Japan  Junior Dance
# 4               The Vision Dance Center     USA  Junior Dance
#
#                Category_Clean Category_Standardized Division  \
# 0  International Junior Dance          Junior Dance   Junior
# 1  International Junior Dance          Junior Dance   Junior
# 2  International Junior Dance          Junior Dance   Junior
# 3  International Junior Dance          Junior Dance   Junior
# 4  International Junior Dance          Junior Dance   Junior
#
#          Studio_Name_Clean                       Team_Name_Clean
# 0     Dancer'S Edge Studio                         Dancer'S Edge
# 1     Dancer'S Edge Studio                  Dancer'S Edge Studio
# 2     Dancer'S Edge Studio  Dancer'S Edge Studio- Junior Lyrical
# 3                   C*Star                          C*Star Artis
# 4  The Vision Dance Center               The Vision Dance Center

# %% [markdown]
# ## Sorting out division

# %%
# Function to clean category names (remove extra spaces, standardise format)
def clean_category(category):
    if pd.isna(category):
        return category
    # Remove extra spaces
    category = re.sub(r'\s+', ' ', str(category)).strip()
    return category

# Apply cleaning
df['Category_Clean'] = df['Category'].apply(clean_category)

# Create mapping dictionary to standardize categories
category_mapping = {
    # Junior Dance variations
    'International Junior Dance': 'Junior Dance',
    'Junior Dance': 'Junior Dance',
    
    # Senior Small Contemporary/Lyrical variations
    'Senior Small Contemporary Lyrical': 'Senior Small Contemporary/Lyrical',
    'Senior Small Contemporary/Lyrical': 'Senior Small Contemporary/Lyrical',
    'Senior Contemporary/Lyrical Small': 'Senior Small Contemporary/Lyrical',
    
    # Senior Large Contemporary/Lyrical variations
    'Senior Large Contemporary Lyrical': 'Senior Large Contemporary/Lyrical',
    'Senior Large Contemporary/Lyrical': 'Senior Large Contemporary/Lyrical',
    'Senior Contemporary/Lyrical Large': 'Senior Large Contemporary/Lyrical',
    
    # Senior Contemporary/Lyrical (no size specified)
    'Senior Contemporary/Lyrical': 'Senior Contemporary/Lyrical',
    
    # Senior Small Hip Hop variations
    'Senior Small Hip Hop': 'Senior Small Hip Hop',
    'Senior Hip Hop Small': 'Senior Small Hip Hop',
    
    # Senior Large Hip Hop variations
    'Senior Large Hip Hop': 'Senior Large Hip Hop',
    'Senior Hip Hop Large': 'Senior Large Hip Hop',
    
    # Senior Small Jazz variations
    'Senior Small Jazz': 'Senior Small Jazz',
    'Senior Jazz Small': 'Senior Small Jazz',
    
    # Senior Large Jazz variations
    'Senior Large Jazz': 'Senior Large Jazz',
    'Senior Jazz Large': 'Senior Large Jazz',
    
    # Senior Jazz (no size)
    'Senior Jazz': 'Senior Jazz',
    
    # Senior Small Pom variations
    'Senior Small Pom': 'Senior Small Pom',
    'Senior Pom Small': 'Senior Small Pom',
    
    # Senior Large Pom variations
    'Senior Large Pom': 'Senior Large Pom',
    'Senior Pom Large': 'Senior Large Pom',
    
    # Senior Pom (no size)
    'Senior Pom': 'Senior Pom',
    
    # Senior Small Coed Hip Hop variations
    'Senior Small Coed Hip Hop': 'Senior Small Coed Hip Hop',
    'Small Senior Coed Hip Hop': 'Senior Small Coed Hip Hop',
    
    # Senior Large Coed Hip Hop variations
    'Senior Large Coed Hip Hop': 'Senior Large Coed Hip Hop',
    'Senior Coed Hip Hop Large': 'Senior Large Coed Hip Hop',
    'Small Large Coed Hip Hop': 'Senior Large Coed Hip Hop',
    
    # Senior Coed Hip Hop Small
    'Senior Coed Hip Hop Small': 'Senior Small Coed Hip Hop',
    
    # Senior Kick
    'Senior Kick': 'Senior Kick',
    
    # Open Contemporary/Lyrical variations
    'International Open Contemporary/Lyrical': 'Open Contemporary/Lyrical',
    'Open Contemporary/Lyrical': 'Open Contemporary/Lyrical',
    'Open Open (Contemporary/Lyrical)': 'Open Contemporary/Lyrical',
    
    # Open Hip Hop variations
    'International Open Hip Hop': 'Open Hip Hop',
    'Open Hip Hop': 'Open Hip Hop',
    
    # Open Jazz variations
    'International Open Jazz': 'Open Jazz',
    'Open Jazz': 'Open Jazz',
    
    # Open Pom variations
    'International Open Pom': 'Open Pom',
    'Open Pom': 'Open Pom',
    
    # Open Kick
    'Open Kick': 'Open Kick',
    
    # Open Coed Hip Hop variations
    'International Open Coed Hip Hop': 'Open Coed Hip Hop',
    'Open Coed Hip Hop': 'Open Coed Hip Hop',
    
    # Open Coed Jazz variations
    'International Open Coed Jazz': 'Open Coed Jazz',
    'Open Coed Jazz': 'Open Coed Jazz',
    
    # Open Coed Pom variations
    'International Open Coed Pom': 'Open Coed Pom',
    'Open Coed Pom': 'Open Coed Pom',
    
    # Open Male Hip Hop
    'International Open Male Hip Hop': 'Open Male Hip Hop',
    'Open Male Hip Hop': 'Open Male Hip Hop',
    
    # Open Elite Contemporary/Lyrical
    'Open Elite Contemporary/Lyrical': 'Open Elite Contemporary/Lyrical',
    
    # Open Elite Hip Hop variations
    'Open Elite Hip Hop': 'Open Elite Hip Hop',
    
    # Open Elite Jazz
    'Open Elite Jazz': 'Open Elite Jazz',
    
    # Open Elite Pom
    'Open Elite Pom': 'Open Elite Pom',
    
    # Open Elite Coed Hip Hop variations
    'Open Elite Coed Hip Hop': 'Open Elite Coed Hip Hop',
    'Open Coed Elite Hip Hop': 'Open Elite Coed Hip Hop',
    
    # Open Premier Contemporary/Lyrical
    'Open Premier Contemporary/Lyrical': 'Open Premier Contemporary/Lyrical',
    
    # Open Premier Hip Hop variations
    'Open Premier Hip Hop': 'Open Premier Hip Hop',
    
    # Open Premier Jazz
    'Open Premier Jazz': 'Open Premier Jazz',
    
    # Open Premier Pom
    'Open Premier Pom': 'Open Premier Pom',
    
    # Open Premier Coed Hip Hop variations
    'Open Premier Coed Hip Hop': 'Open Premier Coed Hip Hop',
    'Open Coed Premier Hip Hop': 'Open Premier Coed Hip Hop',
}

# Apply mapping to create standardized category
def standardize_category(category):
    category_clean = clean_category(category)
    return category_mapping.get(category_clean, category_clean)

df['Category_Standardized'] = df['Category'].apply(standardize_category)

# Show comparison of original vs standardized
print("Category standardization results:\n")
comparison = df[['Category', 'Category_Standardized']].drop_duplicates().sort_values('Category_Standardized')
for _, row in comparison.iterrows():
    if row['Category'] != row['Category_Standardized']:
        print(f"'{row['Category']}' -> '{row['Category_Standardized']}'")

print(f"\nTotal unique standardized categories: {df['Category_Standardized'].nunique()}")

# Show standardized category counts
print("\nStandardized category counts:")
standardized_counts = df['Category_Standardized'].value_counts().sort_index()
for category, count in standardized_counts.items():
    print(f"  {category}: {count} records")

# Save back to original dataframe variable
df.to_csv('dance_worlds_data_20251004_221418.csv', index=False)
# Out:
# Category standardization results:
#
# 'International Junior  Dance' -> 'Junior Dance'
# 'Junior  Dance' -> 'Junior Dance'
# 'International Open Coed Hip Hop' -> 'Open Coed Hip Hop'
# 'International Open Coed Jazz' -> 'Open Coed Jazz'
# 'International Open Coed Pom' -> 'Open Coed Pom'
# 'Open Open (Contemporary/Lyrical)' -> 'Open Contemporary/Lyrical'
# 'Open  Contemporary/Lyrical' -> 'Open Contemporary/Lyrical'
# 'International Open  Contemporary/Lyrical' -> 'Open Contemporary/Lyrical'
# 'Open Coed Elite Hip Hop' -> 'Open Elite Coed Hip Hop'
# 'Open Elite  Hip Hop' -> 'Open Elite Hip Hop'
# 'International Open  Hip Hop' -> 'Open Hip Hop'
# 'Open  Jazz' -> 'Open Jazz'
# 'International Open  Jazz' -> 'Open Jazz'
# 'Open  Kick' -> 'Open Kick'
# 'International Open Male Hip Hop' -> 'Open Male Hip Hop'
# 'Open  Pom' -> 'Open Pom'
# 'International Open  Pom' -> 'Open Pom'
# 'Open Coed Premier Hip Hop' -> 'Open Premier Coed Hip Hop'
# 'Open Premier  Hip Hop' -> 'Open Premier Hip Hop'
# 'Senior  Contemporary/Lyrical' -> 'Senior Contemporary/Lyrical'
# 'Senior  Jazz' -> 'Senior Jazz'
# 'Small Large Coed Hip Hop' -> 'Senior Large Coed Hip Hop'
# 'Senior Coed Hip Hop Large' -> 'Senior Large Coed Hip Hop'
# 'Senior  Contemporary/Lyrical Large' -> 'Senior Large Contemporary/Lyrical'
# 'Senior Large Contemporary Lyrical' -> 'Senior Large Contemporary/Lyrical'
# 'Senior  Hip Hop Large' -> 'Senior Large Hip Hop'
# 'Senior Jazz Large' -> 'Senior Large Jazz'
# 'Senior  Jazz Large' -> 'Senior Large Jazz'
# 'Senior  Pom Large' -> 'Senior Large Pom'
# 'Senior  Pom' -> 'Senior Pom'
# 'Senior Coed Hip Hop Small' -> 'Senior Small Coed Hip Hop'
# 'Small Senior Coed Hip Hop' -> 'Senior Small Coed Hip Hop'
# 'Senior  Contemporary/Lyrical Small' -> 'Senior Small Contemporary/Lyrical'
# 'Senior Small Contemporary Lyrical' -> 'Senior Small Contemporary/Lyrical'
# 'Senior  Hip Hop Small' -> 'Senior Small Hip Hop'
# 'Senior  Jazz Small' -> 'Senior Small Jazz'
# 'Senior  Pom Small' -> 'Senior Small Pom'
#
# Total unique standardized categories: 34
#
# Standardized category counts:
#   Junior Dance: 139 records
#   Open Coed Hip Hop: 72 records
#   Open Coed Jazz: 86 records
#   Open Coed Pom: 81 records
#   Open Contemporary/Lyrical: 87 records
#   Open Elite Coed Hip Hop: 51 records
#   Open Elite Contemporary/Lyrical: 14 records
#   Open Elite Hip Hop: 50 records
#   Open Elite Jazz: 12 records
#   Open Elite Pom: 16 records
#   Open Hip Hop: 68 records
#   Open Jazz: 112 records
#   Open Kick: 14 records
#   Open Male Hip Hop: 39 records
#   Open Pom: 192 records
#   Open Premier Coed Hip Hop: 40 records
#   Open Premier Contemporary/Lyrical: 7 records
#   Open Premier Hip Hop: 31 records
#   Open Premier Jazz: 4 records
#   Open Premier Pom: 11 records
#   Senior Contemporary/Lyrical: 24 records
#   Senior Jazz: 10 records
#   Senior Kick: 12 records
#   Senior Large Coed Hip Hop: 44 records
#   Senior Large Contemporary/Lyrical: 41 records
#   Senior Large Hip Hop: 71 records
#   Senior Large Jazz: 63 records
#   Senior Large Pom: 60 records
#   Senior Pom: 10 records
#   Senior Small Coed Hip Hop: 61 records
#   Senior Small Contemporary/Lyrical: 81 records
#   Senior Small Hip Hop: 119 records
#   Senior Small Jazz: 118 records
#   Senior Small Pom: 113 records

# %%
# List all unique values in Category_Clean
unique_categories_clean = df['Category_Clean'].unique()
print(f"Total unique clean categories: {len(unique_categories_clean)}")
print("\nClean categories:")
for category in sorted(unique_categories_clean):
    count = len(df[df['Category_Clean'] == category])
    print(f"  {category}: {count} records")
# Out:
# Total unique clean categories: 60
#
# Clean categories:
#   International Junior Dance: 41 records
#   International Open Coed Hip Hop: 55 records
#   International Open Coed Jazz: 37 records
#   International Open Coed Pom: 36 records
#   International Open Contemporary/Lyrical: 22 records
#   International Open Hip Hop: 54 records
#   International Open Jazz: 49 records
#   International Open Male Hip Hop: 19 records
#   International Open Pom: 88 records
#   Junior Dance: 98 records
#   Open Coed Elite Hip Hop: 39 records
#   Open Coed Hip Hop: 17 records
#   Open Coed Jazz: 49 records
#   Open Coed Pom: 45 records
#   Open Coed Premier Hip Hop: 28 records
#   Open Contemporary/Lyrical: 32 records
#   Open Elite Coed Hip Hop: 12 records
#   Open Elite Contemporary/Lyrical: 14 records
#   Open Elite Hip Hop: 50 records
#   Open Elite Jazz: 12 records
#   Open Elite Pom: 16 records
#   Open Hip Hop: 14 records
#   Open Jazz: 63 records
#   Open Kick: 14 records
#   Open Male Hip Hop: 20 records
#   Open Open (Contemporary/Lyrical): 33 records
#   Open Pom: 104 records
#   Open Premier Coed Hip Hop: 12 records
#   Open Premier Contemporary/Lyrical: 7 records
#   Open Premier Hip Hop: 31 records
#   Open Premier Jazz: 4 records
#   Open Premier Pom: 11 records
#   Senior Coed Hip Hop Large: 25 records
#   Senior Coed Hip Hop Small: 36 records
#   Senior Contemporary/Lyrical: 24 records
#   Senior Contemporary/Lyrical Large: 8 records
#   Senior Contemporary/Lyrical Small: 13 records
#   Senior Hip Hop Large: 34 records
#   Senior Hip Hop Small: 58 records
#   Senior Jazz: 10 records
#   Senior Jazz Large: 46 records
#   Senior Jazz Small: 55 records
#   Senior Kick: 12 records
#   Senior Large Coed Hip Hop: 14 records
#   Senior Large Contemporary Lyrical: 20 records
#   Senior Large Contemporary/Lyrical: 13 records
#   Senior Large Hip Hop: 37 records
#   Senior Large Jazz: 17 records
#   Senior Large Pom: 35 records
#   Senior Pom: 10 records
#   Senior Pom Large: 25 records
#   Senior Pom Small: 47 records
#   Senior Small Coed Hip Hop: 19 records
#   Senior Small Contemporary Lyrical: 43 records
#   Senior Small Contemporary/Lyrical: 25 records
#   Senior Small Hip Hop: 61 records
#   Senior Small Jazz: 63 records
#   Senior Small Pom: 66 records
#   Small Large Coed Hip Hop: 5 records
#   Small Senior Coed Hip Hop: 6 records

# %%
# List all unique values in Category_Standardized
unique_categories_standardized = df['Category_Standardized'].unique()
print(f"\nTotal unique standardized categories: {len(unique_categories_standardized)}")
print("\nStandardized categories:")
for category in sorted(unique_categories_standardized):
    count = len(df[df['Category_Standardized'] == category])
    print(f"  {category}: {count} records")
# Out:
# Total unique standardized categories: 34
#
# Standardized categories:
#   Junior Dance: 139 records
#   Open Coed Hip Hop: 72 records
#   Open Coed Jazz: 86 records
#   Open Coed Pom: 81 records
#   Open Contemporary/Lyrical: 87 records
#   Open Elite Coed Hip Hop: 51 records
#   Open Elite Contemporary/Lyrical: 14 records
#   Open Elite Hip Hop: 50 records
#   Open Elite Jazz: 12 records
#   Open Elite Pom: 16 records
#   Open Hip Hop: 68 records
#   Open Jazz: 112 records
#   Open Kick: 14 records
#   Open Male Hip Hop: 39 records
#   Open Pom: 192 records
#   Open Premier Coed Hip Hop: 40 records
#   Open Premier Contemporary/Lyrical: 7 records
#   Open Premier Hip Hop: 31 records
#   Open Premier Jazz: 4 records
#   Open Premier Pom: 11 records
#   Senior Contemporary/Lyrical: 24 records
#   Senior Jazz: 10 records
#   Senior Kick: 12 records
#   Senior Large Coed Hip Hop: 44 records
#   Senior Large Contemporary/Lyrical: 41 records
#   Senior Large Hip Hop: 71 records
#   Senior Large Jazz: 63 records
#   Senior Large Pom: 60 records
#   Senior Pom: 10 records
#   Senior Small Coed Hip Hop: 61 records
#   Senior Small Contemporary/Lyrical: 81 records
#   Senior Small Hip Hop: 119 records
#   Senior Small Jazz: 118 records
#   Senior Small Pom: 113 records

# %% [markdown]
# ### Divisions

# %%
# Create Division column based on Category_Standardized
def extract_division(category):
    if pd.isna(category):
        return 'Unknown'
    category_str = str(category).strip()
    
    if category_str.startswith('Senior'):
        return 'Senior'
    elif category_str.startswith('Open'):
        return 'Open'
    elif category_str.startswith('Junior'):
        return 'Junior'
    else:
        return 'Unknown'

df['Division'] = df['Category_Standardized'].apply(extract_division)

# Show division counts
print("Division counts:")
division_counts = df['Division'].value_counts().sort_index()
for division, count in division_counts.items():
    print(f"  {division}: {count} records")

# Show sample of data with Division
print("\nSample data with Division column:")
print(df[['Category_Standardized', 'Division']].head(10))

# Save the updated dataframe
df.to_csv('dance_worlds_data_20251004_221418.csv', index=False)
# Out:
# Division counts:
#   Junior: 139 records
#   Open: 987 records
#   Senior: 827 records
#
# Sample data with Division column:
#   Category_Standardized Division
# 0          Junior Dance   Junior
# 1          Junior Dance   Junior
# 2          Junior Dance   Junior
# 3          Junior Dance   Junior
# 4          Junior Dance   Junior
# 5          Junior Dance   Junior
# 6          Junior Dance   Junior
# 7          Junior Dance   Junior
# 8          Junior Dance   Junior
# 9          Junior Dance   Junior

# %% [markdown]
# ### Team Name and Studio name

# %%
# Function to clean names (basic cleaning)
def clean_name(name):
    if pd.isna(name):
        return name
    
    # Convert to string and strip whitespace
    name = str(name).strip()
    
    # Remove multiple spaces
    name = re.sub(r'\s+', ' ', name)
    
    # Title case (capitalise first letter of each word)
    name = name.title()
    
    # Remove common extra punctuation at the end
    name = name.rstrip('.,;')
    
    return name

# Apply basic cleaning
df['Studio_Name_Clean'] = df['Studio_Name'].apply(clean_name)
df['Team_Name_Clean'] = df['Team_Name'].apply(clean_name)

# Function to calculate similarity between two strings
def similarity(a, b):
    return SequenceMatcher(None, a.lower(), b.lower()).ratio()

# Find potential duplicates
def find_similar_names(name_series, threshold=0.85):
    """Find names that are very similar (potential duplicates)"""
    unique_names = name_series.dropna().unique()
    similar_pairs = []
    
    for i, name1 in enumerate(unique_names):
        for name2 in unique_names[i+1:]:
            sim = similarity(name1, name2)
            if sim >= threshold:
                # Count how many times each appears
                count1 = len(name_series[name_series == name1])
                count2 = len(name_series[name_series == name2])
                similar_pairs.append((name1, count1, name2, count2, sim))
    
    return similar_pairs

# Find studio duplicates
studio_duplicates = find_similar_names(df['Studio_Name_Clean'], threshold=0.85)

if studio_duplicates:
    print(f"Potential studio name duplicates ({len(studio_duplicates)} found):\n")
    for name1, count1, name2, count2, sim in studio_duplicates:
        print(f"  '{name1}' ({count1} records) <-> '{name2}' ({count2} records) - {sim:.1%} similar")
else:
    print("No obvious studio name duplicates found")

# Find team duplicates
print()
team_duplicates = find_similar_names(df['Team_Name_Clean'], threshold=0.85)

if team_duplicates:
    print(f"Potential team name duplicates ({len(team_duplicates)} found):\n")
    for name1, count1, name2, count2, sim in team_duplicates:
        print(f"  '{name1}' ({count1} records) <-> '{name2}' ({count2} records) - {sim:.1%} similar")
else:
    print("No obvious team name duplicates found")

# Show cleaning impact
print(f"\nStudio names - Original unique: {df['Studio_Name'].nunique()}, After cleaning: {df['Studio_Name_Clean'].nunique()}")
print(f"Team names - Original unique: {df['Team_Name'].nunique()}, After cleaning: {df['Team_Name_Clean'].nunique()}")

# Show examples of what changed
studio_changes = df[df['Studio_Name'] != df['Studio_Name_Clean']][['Studio_Name', 'Studio_Name_Clean']].drop_duplicates().head(10)
if len(studio_changes) > 0:
    print("\nExamples of cleaned studio names:")
    for _, row in studio_changes.iterrows():
        print(f"  '{row['Studio_Name']}' -> '{row['Studio_Name_Clean']}'")

team_changes = df[df['Team_Name'] != df['Team_Name_Clean']][['Team_Name', 'Team_Name_Clean']].drop_duplicates().head(10)
if len(team_changes) > 0:
    print("\nExamples of cleaned team names:")
    for _, row in team_changes.iterrows():
        print(f"  '{row['Team_Name']}' -> '{row['Team_Name_Clean']}'")

# Save the updated dataframe
df.to_csv('dance_worlds_data_20251004_221418.csv', index=False)
# Out:
# Potential studio name duplicates (34 found):
#
#   'The Vision Dance Center' (54 records) <-> 'The Vision Dancecenter' (1 records) - 97.8% similar
#   'Kawai Dance Agency Japan' (3 records) <-> 'Kawai Dance Agency' (1 records) - 85.7% similar
#   'Spg Dance Project' (2 records) <-> 'Spg Cheerdance Project' (3 records) - 87.2% similar
#   'Champion Dance & Cheer Allstars' (4 records) <-> 'Champion Dance & Cheer All Stars' (3 records) - 98.4% similar
#   'Dancing Dream Center' (5 records) <-> 'Dancing Dream Center Mexico' (6 records) - 85.1% similar
#   'Music City All Stars' (19 records) <-> 'Music City Allstars' (1 records) - 97.4% similar
#   'Jc Dance And Cheer Academy' (15 records) <-> 'Dance And Cheer Academy' (1 records) - 93.9% similar
#   'Jc Dance And Cheer Academy' (15 records) <-> 'Mcr Dance & Cheer Academy' (2 records) - 86.3% similar
#   'Jordan Johnson Productions' (6 records) <-> 'Jordan Johnosn Productions' (1 records) - 96.2% similar
#   'Angels Dance Academy (Ada)' (7 records) <-> 'Angels Dance Academy' (25 records) - 87.0% similar
#   'Legendary Athletics North' (11 records) <-> 'Legendary Athletics' (10 records) - 86.4% similar
#   'Legendary Athletics North' (11 records) <-> 'Legendary Athletics North (Fl)' (2 records) - 90.9% similar
#   'Adrenaline All Stars' (9 records) <-> 'Adrenaline Allstars' (6 records) - 97.4% similar
#   'Ecole De Danse Dan Zaa' (2 records) <-> 'Ecole De Danse Dan-Zaa' (4 records) - 95.5% similar
#   'Fire Wings' (2 records) <-> 'Firewings' (4 records) - 94.7% similar
#   'Cheer Label Langenfeld' (1 records) <-> 'Cheer Label Langenfeld E.V' (1 records) - 91.7% similar
#   'World Wings' (4 records) <-> 'Worldwings' (1 records) - 95.2% similar
#   'Hy-Fidelity Dance' (1 records) <-> 'Hyfidelity Dance' (4 records) - 97.0% similar
#   'Ydc Dance Studio' (3 records) <-> 'Mds Dance Studio' (3 records) - 87.5% similar
#   'Ydc Dance Studio' (3 records) <-> 'Dms Dance Studio' (1 records) - 87.5% similar
#   'Ydc Dance Studio' (3 records) <-> 'Nca Dance Studio' (1 records) - 87.5% similar
#   'Cheers Factory' (6 records) <-> 'Cheer Factory' (1 records) - 96.3% similar
#   'Pittsburgh Poison All Stars' (18 records) <-> 'Pittsburgh Pride All Stars' (11 records) - 86.8% similar
#   'Mds Dance Studio' (3 records) <-> 'Mathis Dance Studio' (2 records) - 85.7% similar
#   'Mds Dance Studio' (3 records) <-> 'Dms Dance Studio' (1 records) - 93.8% similar
#   'Mathis Dance Studio' (2 records) <-> 'Dms Dance Studio' (1 records) - 85.7% similar
#   'Power Of Dance Llc' (11 records) <-> 'Power Of Dance' (8 records) - 87.5% similar
#   'Dancin With Roxie' (14 records) <-> 'Dancin' With Roxie' (2 records) - 97.1% similar
#   'Midwest Cheer Elite Xenia' (1 records) <-> 'Midwest Cheer Elite' (3 records) - 86.4% similar
#   'Nrg Studios' (1 records) <-> 'Tg Studios' (1 records) - 85.7% similar
#   'Epa All Stars' (1 records) <-> 'Epa Allstars' (3 records) - 96.0% similar
#   'Dance Etc' (1 records) <-> 'Dance Etc Ky' (1 records) - 85.7% similar
#   'Danzforce Academy Ca' (2 records) <-> 'Danzforce Academy Tx' (1 records) - 90.0% similar
#   'Premier Athletics' (3 records) <-> 'Premier Athletics Nky' (1 records) - 89.5% similar
#
# Potential team name duplicates (365 found):
#
#   'Dancer'S Edge' (1 records) <-> 'Dancers Edge' (1 records) - 96.0% similar
#   'Dancer'S Edge Studio' (6 records) <-> 'Dancer'S Edge Studio - Slj' (1 records) - 87.0% similar
#   'Dancer'S Edge Studio' (6 records) <-> 'Dancers Edge Studio' (1 records) - 97.4% similar
#   'Dancin' Bluebonnets - Open Jazz' (1 records) <-> 'Dancin' Bluebonnets - Oj' (1 records) - 87.3% similar
#   'Dancin' Bluebonnets - Open Jazz' (1 records) <-> 'Dancin' Bluebonnets - Ocj' (1 records) - 85.7% similar
#   'Dancin' Bluebonnets' (5 records) <-> 'Dancin Bluebonnets' (11 records) - 97.3% similar
#   'Dancin' Bluebonnets' (5 records) <-> 'Dancin’ Bluebonnets' (3 records) - 94.7% similar
#   'Dancin' Bluebonnets' (5 records) <-> 'Dancin' Bluebonnets - Oj' (1 records) - 88.4% similar
#   'Dancin' Bluebonnets' (5 records) <-> 'Dancin' Bluebonnets - Ocj' (1 records) - 86.4% similar
#   'Dancin' Bluebonnets' (5 records) <-> 'Dancin’ Blue Bonnets' (1 records) - 92.3% similar
#   'Dancin' Bluebonnets' (5 records) <-> 'Dancin' Bluebonnets - Ssj' (1 records) - 86.4% similar
#   'Abe Dance Promotion- Blue Star' (1 records) <-> 'Abe Dance Promotion - Blue Force' (2 records) - 87.1% similar
#   'South Coast Freestyle' (14 records) <-> 'South Coast Freestyle - Op' (1 records) - 89.4% similar
#   'South Coast Freestyle' (14 records) <-> 'South Coast Freestyle - Sscl' (1 records) - 85.7% similar
#   'South Coast Freestyle' (14 records) <-> 'South Coast Freestyle - Ssj' (1 records) - 87.5% similar
#   'South Coast Freestyle' (14 records) <-> 'South Coast Freestyle- Diana' (1 records) - 85.7% similar
#   'Golden Hawks Jr' (1 records) <-> 'Golden Hawks' (10 records) - 88.9% similar
#   'Jexer Fitness Cuib Omiya - Zingys' (1 records) <-> 'Jexer Fitness Cuib Omiya Zingys' (1 records) - 96.9% similar
#   'Jexer Fitness Cuib Omiya - Zingys' (1 records) <-> 'Jexer Fitness Club Omiya – Zingys' (1 records) - 93.9% similar
#   'Strut Performing Arts Center- Junior Hip Hop' (1 records) <-> 'Strut Performing Arts – Senior Hip Hop' (1 records) - 85.4% similar
#   'Jexer Fitness Cuib Omiya Zingys' (1 records) <-> 'Jexer Fitness Club Omiya – Zingys' (1 records) - 93.8% similar
#   'Centro Artistico Yesenea Mendoza - I Believe' (1 records) <-> 'Centro Artistico Yesenea Mendoza - Survivor' (1 records) - 85.1% similar
#   'Centro Artistico Yesenea Mendoza - I Believe' (1 records) <-> 'Centro Artistico Yesenea Mendoza - This Is Me' (1 records) - 85.4% similar
#   'Centro Artistico Yesenea Mendoza - I Believe' (1 records) <-> 'Centro Artistico Yesenea Mendoza - Dem Beats' (1 records) - 86.4% similar
#   'Centro Artistico Yesenea Mendoza' (7 records) <-> 'Centro Artistico Yesenea Mendoza – For My H' (1 records) - 85.3% similar
#   'Centro Artistico Yesenea Mendoza' (7 records) <-> 'Centro Artistico Yesenea Mendoza - Ramalama' (1 records) - 85.3% similar
#   'Centro Artistico Yesenea Mendoza' (7 records) <-> 'Centro Artistico Yesenea Mendoza - Survivor' (1 records) - 85.3% similar
#   'Centro Artistico Yesenea Mendoza' (7 records) <-> 'Centro Artã­Stico Yesenea Mendoza' (1 records) - 95.4% similar
#   'Champion Dance And Cheer All Stars' (1 records) <-> 'Champion Dance And All Stars' (1 records) - 90.3% similar
#   'Rokkaz- Junior Rokkaz' (1 records) <-> 'Rokkaz – Junior Rokkaz' (1 records) - 93.0% similar
#   'Ceam Mexico- Team 1' (1 records) <-> 'Ceam Mexico- Team 2' (1 records) - 94.7% similar
#   'Dance Dynamics' (23 records) <-> 'Dane Dynamics' (1 records) - 96.3% similar
#   'Dance Dynamics' (23 records) <-> 'Dance Dynamixs' (1 records) - 92.9% similar
#   'Dance Dynamics' (23 records) <-> 'Dance Dynamic' (1 records) - 96.3% similar
#   'Dancin Bluebonnets' (11 records) <-> 'Dancin’ Bluebonnets' (3 records) - 97.3% similar
#   'Dancin Bluebonnets' (11 records) <-> 'Dancin' Bluebonnets - Oj' (1 records) - 85.7% similar
#   'Dancin Bluebonnets' (11 records) <-> 'Dancin’ Blue Bonnets' (1 records) - 94.7% similar
#   'Mt. Eden Ballet Academey' (1 records) <-> 'Mt. Eden Ballet Academy' (2 records) - 97.9% similar
#   'Mt. Eden Ballet Academey' (1 records) <-> 'Mt Eden Ballet Academy - Jd' (1 records) - 86.3% similar
#   'Mt. Eden Ballet Academey' (1 records) <-> 'Mt Eden Ballet Academy - Oj' (1 records) - 86.3% similar
#   'Dancin’ Bluebonnets' (3 records) <-> 'Dancin’ Blue Bonnets' (1 records) - 97.4% similar
#   'Music City All Stars' (11 records) <-> 'Music City All Stars - Slcl' (1 records) - 85.1% similar
#   'Music City All Stars' (11 records) <-> 'Music City Allstars' (3 records) - 97.4% similar
#   'Music City All Stars' (11 records) <-> 'Music City All Stars - Slp' (1 records) - 87.0% similar
#   'Dsf – Dsf Brilliants' (1 records) <-> 'Dsf – Dsf Brilliants Sr' (1 records) - 93.0% similar
#   'Mathis Dance Studio' (2 records) <-> 'Mds Dance Studio' (3 records) - 85.7% similar
#   'Ultimate Dance Centre – Ultimate Rock Stars' (2 records) <-> 'Ultimate Dance Centre – Glitter Stars' (1 records) - 87.5% similar
#   'Ultimate Dance Centre – Ultimate Rock Stars' (2 records) <-> 'Ultimate Dance Centre - Ultimate Rock Stars' (2 records) - 97.7% similar
#   'Centro Artistico Yesenea Mendoza – For My H' (1 records) <-> 'Centro Artistico Yesenea Mendoza - Tore My Heart' (1 records) - 90.1% similar
#   'Toxic Cheer And Dance' (1 records) <-> 'Toxic Cheer & Dance' (1 records) - 90.0% similar
#   'Rsd Action – Rsd Leading Ladies' (3 records) <-> 'Rsd Action - Leading Ladies' (2 records) - 89.7% similar
#   'Rsd Action – Rsd Leading Ladies' (3 records) <-> 'Rsd Action- Rsd Leading Ladies' (1 records) - 95.1% similar
#   'Jc Dance And Cheer Academy' (1 records) <-> 'Jc Dance And Cheer Academy - White' (1 records) - 86.7% similar
#   'Balleteatro Dominco' (1 records) <-> 'Balleteatro Dominicano' (1 records) - 92.7% similar
#   'Jordan Johnson Productions - Fly' (1 records) <-> 'Jordan Johnson Productions' (2 records) - 89.7% similar
#   'Jordan Johnson Productions - Fly' (1 records) <-> 'Jordan Johnson Productions - Crew' (1 records) - 89.2% similar
#   'Jordan Johnson Productions - Fly' (1 records) <-> 'Jordan Johnosn Productions Fly Kids' (1 records) - 86.6% similar
#   'Planets - Ohh' (1 records) <-> 'Planets - Op' (1 records) - 88.0% similar
#   'Angels Dance Academy – Dominion' (1 records) <-> 'Angels Dance Academy - Ada Dominion' (1 records) - 90.9% similar
#   'Star Performance Centre' (17 records) <-> 'Star Performance Centre - Slj' (1 records) - 88.5% similar
#   'Star Performance Centre' (17 records) <-> 'Star Performance Centre - Slp' (1 records) - 88.5% similar
#   'Star Performance Centre' (17 records) <-> 'Star Performance Centre - Schh' (1 records) - 86.8% similar
#   'Dollhouse Dance Factory' (5 records) <-> 'Dollhouse Dance Factory - Hype' (1 records) - 86.8% similar
#   'Dancer’S Edge – De 3' (1 records) <-> 'Dancer'S Edge - De3' (1 records) - 87.2% similar
#   'Dancer’S Edge – De 3' (1 records) <-> 'Dancers Edge - De.3' (1 records) - 87.2% similar
#   'Dollhouse Dance Factory – Evil Queen' (1 records) <-> 'Dollhouse Dance Factory – Sirens' (1 records) - 85.3% similar
#   'Dancer'S Edge - De3' (1 records) <-> 'Dancers Edge - De.3' (1 records) - 94.7% similar
#   'Adrenaline Allstars' (1 records) <-> 'Adrenaline Allstars Blaze' (1 records) - 86.4% similar
#   'Oblivion All Stars – Storm' (1 records) <-> 'Oblivion Allstars - Storm' (1 records) - 94.1% similar
#   'Ecole De Danse Dan Zaa – No Rules' (1 records) <-> 'Ecole De Danse Dan-Zaa - No Rules' (1 records) - 93.9% similar
#   'Cheer Label Lagenfeld E.V' (1 records) <-> 'Cheer Label Langenfeld' (1 records) - 89.4% similar
#   'Wing Dance Promotion - Silver Wings' (2 records) <-> 'Wing Dance Production – Silver Wings' (1 records) - 90.1% similar
#   'Wing Dance Promotion - Silver Wings' (2 records) <-> 'Wing Dance Promotion- Silver Wings' (1 records) - 98.6% similar
#   'Wing Dance Promotion - Silver Wings' (2 records) <-> 'Wing Dance Promotion Silver Wings - Oj' (1 records) - 90.4% similar
#   'Wing Dance Promotion - Silver Wings' (2 records) <-> 'Wing Dance Promotion Silver Wings - Op' (1 records) - 90.4% similar
#   'Wing Dance Promotion - Silver Wings' (2 records) <-> 'Wing Dance Promotion - Silver Wings Aile' (1 records) - 93.3% similar
#   'Top Dance - Td&B All Stars' (1 records) <-> 'Top Dance – Td&B All Stars' (1 records) - 96.2% similar
#   'Mt. Eden Ballet Academy' (2 records) <-> 'Mt Eden Ballet Academy - Jd' (1 records) - 88.0% similar
#   'Mt. Eden Ballet Academy' (2 records) <-> 'Mt Eden Ballet Academy - Oj' (1 records) - 88.0% similar
#   'Brisbane School Of Dance – Ultimate Uproar' (1 records) <-> 'Brisbane School Of Dance - Ultimate Uproar' (1 records) - 97.6% similar
#   'Cheertastic Dance And Cheerleading - Dream Stars' (1 records) <-> 'Cheertastic Dance And Cheerleading - Rock Stars' (1 records) - 92.6% similar
#   'Sharon Ann Academy Of Cheer & Dance – Sa' (1 records) <-> 'Sharon Ann Academy Of Cheer & Dance - Sa Supreme' (2 records) - 88.6% similar
#   'Rsd Action - Leading Ladies' (2 records) <-> 'Rsd Action- Rsd Leading Ladies' (1 records) - 91.2% similar
#   'Rsd Action - Leading Ladies' (2 records) <-> 'Rsd - Leading Ladies' (3 records) - 85.1% similar
#   'The Golden Girls' (3 records) <-> 'Golden Girls' (4 records) - 85.7% similar
#   'Jc Dance And Cheer Academy - Glitter White' (1 records) <-> 'Jc Dance And Cheer Academy- Jc Glitter White' (1 records) - 95.3% similar
#   'Jc Dance And Cheer Academy - Glitter White' (1 records) <-> 'Jc Dance And Cheer Academy - White' (1 records) - 89.5% similar
#   'Jc Dance And Cheer Academy - Glitter White' (1 records) <-> 'Jc Dance And Cheer Academy - Jc Glitter White' (1 records) - 96.6% similar
#   'Energizers Dance Team' (5 records) <-> 'Energizers Dance Team Test' (1 records) - 89.4% similar
#   'Energizers- Open Pom' (1 records) <-> 'Energizers- Senior Pom' (1 records) - 85.7% similar
#   'Wing Dance Production – Silver Wings' (1 records) <-> 'Wing Dance Promotion- Silver Wings' (1 records) - 88.6% similar
#   'Wing Dance Promotion- Silver Wings' (1 records) <-> 'Wing Dance Promotion Silver Wings - Oj' (1 records) - 91.7% similar
#   'Wing Dance Promotion- Silver Wings' (1 records) <-> 'Wing Dance Promotion Silver Wings - Op' (1 records) - 91.7% similar
#   'Wing Dance Promotion- Silver Wings' (1 records) <-> 'Wing Dance Promotion - Silver Wings Aile' (1 records) - 91.9% similar
#   'Starz Dance Academy – Starz Elite' (2 records) <-> 'Starz Dance Academy - Elite' (2 records) - 86.7% similar
#   'Gold Star- Galaxy' (1 records) <-> 'Gold Star - Galaxy' (1 records) - 97.1% similar
#   'Gold Star- Galaxy' (1 records) <-> 'Gold Star Galaxy' (3 records) - 97.0% similar
#   'Jc Dance And Cheer Academy- Jc Glitter White' (1 records) <-> 'Jc Dance And Cheer Academy - Jc Glitter White' (1 records) - 98.9% similar
#   'Gold Star - Galaxy' (1 records) <-> 'Gold Star Galaxy' (3 records) - 94.1% similar
#   'Phoenix Flames – Elite' (1 records) <-> 'Phoenix Flames - Elite' (1 records) - 95.5% similar
#   'Phoenix Flames – Elite' (1 records) <-> 'Phoenix Flames Elite' (2 records) - 95.2% similar
#   'Golden Dance Academy - Golden Girls' (1 records) <-> 'Golden Dance Academy – Golden Girls' (1 records) - 97.1% similar
#   'Hawks Cheer And Dance – Intensity Diamonds' (1 records) <-> 'Hawks Cheer And Dance - Hawks Intensity Diamonds' (1 records) - 91.1% similar
#   'Jc Dance And Cheer Academy - White' (1 records) <-> 'Jc Dance And Cheer Academy - Jc Glitter White' (1 records) - 86.1% similar
#   'Electric Girls Dance' (1 records) <-> 'Electric Girls Dance - Jd' (1 records) - 88.9% similar
#   'Kif Dance - Kif Studio 3 Magnetic' (1 records) <-> 'Kif Dans - Kif Studio3 Magnetic' (1 records) - 93.8% similar
#   'Wolves Army Cheer' (1 records) <-> 'Wolves Army Cheer - Op' (1 records) - 87.2% similar
#   'Next Level Dance Co - Supremacy' (2 records) <-> 'Next Level Dance Co – Supremacy' (1 records) - 96.8% similar
#   'Next Level Dance Co - Supremacy' (2 records) <-> 'Next Level Dance Co.- Supremecy' (1 records) - 93.5% similar
#   'Next Level Dance Co - Supremacy' (2 records) <-> 'Next Level Dance Co Supremacy' (1 records) - 96.7% similar
#   'Ada - Dark Angels' (1 records) <-> 'Ada Dark Angels' (5 records) - 93.8% similar
#   'Pittsburgh Poison - Black Frogs' (1 records) <-> 'Pittsburgh Poison - Black Widows' (2 records) - 88.9% similar
#   'Pittsburgh Poison - Black Frogs' (1 records) <-> 'Pittsburgh Poison - Dart Frogs' (2 records) - 88.5% similar
#   'Jordan Johnson Productions' (2 records) <-> 'Jordan Johnson Productions - Crew' (1 records) - 88.1% similar
#   'Next Level Dance Co – Supremacy' (1 records) <-> 'Next Level Dance Co.- Supremecy' (1 records) - 90.3% similar
#   'Next Level Dance Co – Supremacy' (1 records) <-> 'Next Level Dance Co Supremacy' (1 records) - 96.7% similar
#   'Next Level Dance Co.- Supremecy' (1 records) <-> 'Next Level Dance Co Supremacy' (1 records) - 93.3% similar
#   'Angels Dance Academy – Dark Angels' (1 records) <-> 'Angels Dance Academy - Ada Dark Angels' (1 records) - 91.7% similar
#   'Strut Performing Arts' (10 records) <-> 'Strut Performing Arts Center' (3 records) - 85.7% similar
#   'Strut Performing Arts' (10 records) <-> 'Strut Performing Arts - Ocj' (1 records) - 87.5% similar
#   'Strut Performing Arts' (10 records) <-> 'Strut Performing Arts - Ocp' (1 records) - 87.5% similar
#   'Strut Performing Arts' (10 records) <-> 'Strut Performing Arts - Sshh' (1 records) - 85.7% similar
#   'Strut Performing Arts' (10 records) <-> 'Strut Performing Arts - Ssp' (1 records) - 87.5% similar
#   'Strut Performing Arts' (10 records) <-> 'Strut Performance Arts' (1 records) - 88.4% similar
#   'Rs Studio All Star' (2 records) <-> 'Rs Studio All Star - Ocj' (1 records) - 85.7% similar
#   'Universidad Politecnica Salesiana' (1 records) <-> 'Universidad Politecnica Salesiana - Ocphh' (1 records) - 89.2% similar
#   'Centro Artistico Yesenea Mendoza - Tore My Heart' (1 records) <-> 'Centro Artistico Yesenea Mendoza - Dem Beats' (1 records) - 87.0% similar
#   'Dreamtyme - Dream Elite' (1 records) <-> 'Dreamtyme - Dreamelite' (1 records) - 97.8% similar
#   'Strut Performing Arts – Open Coed Pom' (1 records) <-> 'Strut Performing Arts - Open Coed Hip Hop' (1 records) - 89.7% similar
#   'Strut Performing Arts – Open Coed Pom' (1 records) <-> 'Strut Performing Arts – Senior Pom' (1 records) - 87.3% similar
#   'Velocity Dance – Woop' (1 records) <-> 'Velocity Dance - Woop' (2 records) - 95.2% similar
#   'Velocity Dance – Woop' (1 records) <-> 'Velocity Dance - Woah' (1 records) - 85.7% similar
#   'Pittsburgh Poison All Stars- King Cobras' (1 records) <-> 'Pittsburgh Poison All Stars – King Cobras' (1 records) - 96.3% similar
#   'Pittsburgh Poison All Stars- King Cobras' (1 records) <-> 'Pittsburgh Poison All Stars - King Cobras' (1 records) - 98.8% similar
#   'Pittsburgh Poison All Stars – King Cobras' (1 records) <-> 'Pittsburgh Poison All Stars - King Cobras' (1 records) - 97.6% similar
#   'Pittsburgh Poison All Stars – King Cobras' (1 records) <-> 'Pittsburgh Poison All Stars – Nyah' (1 records) - 85.3% similar
#   'Power House Of Dance - Crew' (1 records) <-> 'Power House Of Dance - Street' (1 records) - 89.3% similar
#   'Adrenaline All Stars- Rush Crew' (1 records) <-> 'Adrenaline Allstars – Rush Crew' (1 records) - 93.5% similar
#   'Adrenaline All Stars- Rush Crew' (1 records) <-> 'Adrenaline All Stars - Rush Crew' (1 records) - 98.4% similar
#   'Adrenaline All Stars- Rush Crew' (1 records) <-> 'Adrenaline Allstars - Rush Crew' (1 records) - 96.8% similar
#   'Adrenaline Allstars – Rush Crew' (1 records) <-> 'Adrenaline All Stars - Rush Crew' (1 records) - 95.2% similar
#   'Adrenaline Allstars – Rush Crew' (1 records) <-> 'Adrenaline Allstars - Rush Crew' (1 records) - 96.8% similar
#   'Adrenaline All Stars - Rush Crew' (1 records) <-> 'Adrenaline Allstars - Rush Crew' (1 records) - 98.4% similar
#   'Adrenaline All Stars - Rush Crew' (1 records) <-> 'Adrenaline All Stars - Thunder Crew' (1 records) - 86.6% similar
#   'Dancer’S Edge Studio – Junior Jazz' (1 records) <-> 'Dancer'S Edge Studio - Junior Small Jazz' (1 records) - 86.5% similar
#   'Dancer’S Edge Studio – Junior Jazz' (1 records) <-> 'Dancer’S Edge Studio – Senior Large Jazz' (1 records) - 86.5% similar
#   'Dancer'S Edge Studio - Junior Small Jazz' (1 records) <-> 'Dancer'S Edge Studio- Senior Small Jazz' (1 records) - 93.7% similar
#   'Mt Eden Ballet Academy - Jd' (1 records) <-> 'Mt Eden Ballet Academy - Oocl' (1 records) - 89.3% similar
#   'Mt Eden Ballet Academy - Jd' (1 records) <-> 'Mt Eden Ballet Academy - Oj' (1 records) - 96.3% similar
#   'Mt Eden Ballet Academy - Jd' (1 records) <-> 'Mt Eden Ballet Academy - Slcl' (1 records) - 89.3% similar
#   'Mt Eden Ballet Academy - Jd' (1 records) <-> 'Mt Eden Ballet Academy - Sscl' (1 records) - 89.3% similar
#   'Academia De Baile Seven Dancers - Jd' (1 records) <-> 'Academia De Baile – Seven Dancers' (1 records) - 89.9% similar
#   'Academia De Baile Seven Dancers - Jd' (1 records) <-> 'Academia De Baile Seven Dancers - Ocphh' (1 records) - 90.7% similar
#   'Academia De Baile – Seven Dancers' (1 records) <-> 'Academia De Baile Seven Dancers - Ocphh' (1 records) - 86.1% similar
#   'Ultimate Dance Centre – Glitter Stars' (1 records) <-> 'Ultimate Dance Centre - Ultimate Rock Stars' (2 records) - 85.0% similar
#   'Dancing Dream Center Mexico - Jd' (1 records) <-> 'Dancing Dream Center Mexico - Op' (1 records) - 93.8% similar
#   'Colegio Nueva York - Jd' (1 records) <-> 'Colegio Nueva York - Ok' (1 records) - 91.3% similar
#   'The Brand Dance Company - Jd' (1 records) <-> 'The Brand Dance Company - Oj' (1 records) - 96.4% similar
#   'The Brand Dance Company - Jd' (1 records) <-> 'The Brand Dance Company - Op' (1 records) - 92.9% similar
#   'Junior Team Jazz' (1 records) <-> 'Senior Team Jazz' (1 records) - 87.5% similar
#   'Junior All Stars' (1 records) <-> 'Senior All Stars' (15 records) - 87.5% similar
#   'Pittsburgh Poison All Stars - Scorpions' (1 records) <-> 'Pittsburgh Poison All Stars - King Cobras' (1 records) - 85.0% similar
#   'Junior Premier' (1 records) <-> 'Senior Premier' (3 records) - 85.7% similar
#   'Golden Girls' (4 records) <-> 'Golden Girls Jd' (1 records) - 88.9% similar
#   'Golden Girls' (4 records) <-> 'Golden Girls Oep' (1 records) - 85.7% similar
#   'The Vision Dance Center - Open Allstars' (2 records) <-> 'The Vision Dance Center Allstars' (11 records) - 90.1% similar
#   'The Vision Dance Center - Open Allstars' (2 records) <-> 'The Vision Dance Center All Stars' (2 records) - 88.9% similar
#   'The Vision Dance Center - Open Allstars' (2 records) <-> 'The Vision Dance Center - Senior Allstars' (2 records) - 92.5% similar
#   'Mt Eden Ballet Academy - Oocl' (1 records) <-> 'Mt Eden Ballet Academy - Oj' (1 records) - 92.9% similar
#   'Mt Eden Ballet Academy - Oocl' (1 records) <-> 'Mt Eden Ballet Academy - Slcl' (1 records) - 93.1% similar
#   'Mt Eden Ballet Academy - Oocl' (1 records) <-> 'Mt Eden Ballet Academy - Sscl' (1 records) - 93.1% similar
#   'Cfu Ukraine - Oocl' (1 records) <-> 'Cfu Ukraine - Oj' (1 records) - 88.2% similar
#   'Cfu Ukraine - Oocl' (1 records) <-> 'Cfu Ukraine - Op' (1 records) - 88.2% similar
#   'Golden Girls - Oocl' (1 records) <-> 'Golden Girls - Op' (1 records) - 88.9% similar
#   'Wing Dance Promotion Silver Wings - Oj' (1 records) <-> 'Wing Dance Promotion Silver Wings - Op' (1 records) - 97.4% similar
#   'Wing Dance Promotion Silver Wings - Oj' (1 records) <-> 'Wing Dance Promotion - Silver Wings Aile' (1 records) - 87.2% similar
#   'Dancin' Bluebonnets - Oj' (1 records) <-> 'Dancin' Bluebonnets - Ocj' (1 records) - 98.0% similar
#   'Dancin' Bluebonnets - Oj' (1 records) <-> 'Dancin' Bluebonnets - Ssj' (1 records) - 93.9% similar
#   'Mt Eden Ballet Academy - Oj' (1 records) <-> 'Mt Eden Ballet Academy - Slcl' (1 records) - 89.3% similar
#   'Mt Eden Ballet Academy - Oj' (1 records) <-> 'Mt Eden Ballet Academy - Sscl' (1 records) - 89.3% similar
#   'Dance Dynamics - Oj' (1 records) <-> 'Dance Dynamics - Slj' (1 records) - 92.3% similar
#   'Dance Dynamics - Oj' (1 records) <-> 'Dance Dynamics - Ssj' (1 records) - 92.3% similar
#   'Cfu Ukraine - Oj' (1 records) <-> 'Cfu Ukraine - Op' (1 records) - 93.8% similar
#   'Dance Deluxe - Oj' (1 records) <-> 'Dance Deluxe - Op' (1 records) - 94.1% similar
#   'The Brand Dance Company - Oj' (1 records) <-> 'The Brand Dance Company - Op' (1 records) - 96.4% similar
#   'Energizers - Ok' (1 records) <-> 'Energizers - Op' (1 records) - 93.3% similar
#   'Foursis Dance Academy - Dazzler Dance Team' (4 records) <-> 'Foursis Dance Academy – Dazzler Dance Team' (1 records) - 97.6% similar
#   'Wing Dance Promotion Silver Wings - Op' (1 records) <-> 'Wing Dance Promotion - Silver Wings Aile' (1 records) - 87.2% similar
#   'Energizers - Op' (1 records) <-> 'Energizers - Slp' (1 records) - 90.3% similar
#   'Energizers - Op' (1 records) <-> 'Energizers - Ssp' (1 records) - 90.3% similar
#   'South Coast Freestyle - Op' (1 records) <-> 'South Coast Freestyle - Sscl' (1 records) - 88.9% similar
#   'South Coast Freestyle - Op' (1 records) <-> 'South Coast Freestyle - Ssj' (1 records) - 90.6% similar
#   'South Coast Freestyle - Op' (1 records) <-> 'South Coast Freestyle- Diana' (1 records) - 85.2% similar
#   'Dance Factory - Op' (1 records) <-> 'Dance Factory - Ocj' (1 records) - 91.9% similar
#   'Dance Factory - Op' (1 records) <-> 'Dance Factory - Ocp' (1 records) - 97.3% similar
#   'Dance Factory - Op' (1 records) <-> 'Dance Factory - Ocphh' (1 records) - 92.3% similar
#   'Phoenix Flames - Elite' (1 records) <-> 'Phoenix Flames Elite' (2 records) - 95.2% similar
#   'Golden Girls - Op' (1 records) <-> 'Golden Girls Oep' (1 records) - 90.9% similar
#   'Pittsburgh Poison All Stars' (3 records) <-> 'Pittsburgh Poison All Stars – Nyah' (1 records) - 88.5% similar
#   'Pittsburgh Poison All Stars' (3 records) <-> 'Pittsburgh Poison All Stars - Nyah' (1 records) - 88.5% similar
#   'Pittsburgh Poison All Stars' (3 records) <-> 'Pittsburgh Poison All Stars Cyanide' (1 records) - 87.1% similar
#   'Velocity Dance Swag' (1 records) <-> 'Velocity Dance - Woah' (1 records) - 85.0% similar
#   'Velocity Dance Swag' (1 records) <-> 'Velocity Dance - Swag' (2 records) - 95.0% similar
#   'Take Off' (2 records) <-> 'Takeoff' (2 records) - 93.3% similar
#   'Dms Crew' (1 records) <-> 'Eds Crew' (1 records) - 87.5% similar
#   'Dance Factory - Ocj' (1 records) <-> 'Dance Factory - Ocp' (1 records) - 94.7% similar
#   'Dance Factory - Ocj' (1 records) <-> 'Dance Factory - Ocphh' (1 records) - 90.0% similar
#   'Dancin' Bluebonnets - Ocj' (1 records) <-> 'Dancin' Bluebonnets - Ssj' (1 records) - 92.0% similar
#   'Strut Performing Arts - Ocj' (1 records) <-> 'Strut Performing Arts - Ocp' (1 records) - 96.3% similar
#   'Strut Performing Arts - Ocj' (1 records) <-> 'Strut Performing Arts - Sshh' (1 records) - 87.3% similar
#   'Strut Performing Arts - Ocj' (1 records) <-> 'Strut Performing Arts - Ssp' (1 records) - 88.9% similar
#   'Strut Performing Arts - Ocj' (1 records) <-> 'Strut Performing Arts - Sschh' (1 records) - 89.3% similar
#   '5678! Dance Studio - Open All Stars' (1 records) <-> '5678! Dance Studio – Senior All Stars' (3 records) - 88.9% similar
#   '5678! Dance Studio - Open All Stars' (1 records) <-> '5678! Dance Studio - Senior All Stars' (3 records) - 91.7% similar
#   'Dance Factory - Ocp' (1 records) <-> 'Dance Factory - Ocphh' (1 records) - 95.0% similar
#   'Velocity Dance - Woop' (2 records) <-> 'Velocity Dance - Woah' (1 records) - 90.5% similar
#   'Velocity Dance - Woop' (2 records) <-> 'Velocity Dance - Wolfpack' (1 records) - 87.0% similar
#   'Velocity Dance - Woop' (2 records) <-> 'Velocity Dance - Swag' (2 records) - 85.7% similar
#   'Strut Performing Arts - Ocp' (1 records) <-> 'Strut Performing Arts - Sshh' (1 records) - 87.3% similar
#   'Strut Performing Arts - Ocp' (1 records) <-> 'Strut Performing Arts - Ssp' (1 records) - 92.6% similar
#   'Strut Performing Arts - Ocp' (1 records) <-> 'Strut Performing Arts - Sschh' (1 records) - 89.3% similar
#   'Adrenaline Allstars Fusion' (1 records) <-> 'Adrenaline Allstars - Fusion' (1 records) - 96.3% similar
#   'Open Coed Premier Hip Hop' (1 records) <-> 'Open Premier Hip Hop' (1 records) - 88.9% similar
#   'Brilliants' (2 records) <-> 'Brilliants Sr' (1 records) - 87.0% similar
#   'Legendary Athletics - Open Elite' (1 records) <-> 'Legendary Athletics – Senior Elite' (1 records) - 87.9% similar
#   'Estilo Urbano - Oehh' (1 records) <-> 'Estilo Urbano - Ocehh' (1 records) - 97.6% similar
#   'Peppermint Dance Company - Valkryie' (1 records) <-> 'Peppermint Dance Company - Exiled' (1 records) - 85.3% similar
#   'Tanz Regens - Oehh' (1 records) <-> 'Tanz Regens - Omhh' (1 records) - 94.4% similar
#   'Strut Performing Arts - Open Coed Hip Hop' (1 records) <-> 'Strut Performing Arts – Senior Hip Hop' (1 records) - 86.1% similar
#   'Velocity Dance - Woah' (1 records) <-> 'Velocity Dance - Wolfpack' (1 records) - 87.0% similar
#   'Velocity Dance - Woah' (1 records) <-> 'Velocity Dance - Swag' (2 records) - 90.5% similar
#   'Adrenaline Allstars - Rage' (1 records) <-> 'Adrenaline Allstars - Havoc' (1 records) - 86.8% similar
#   'Adrenaline Allstars - Rage' (1 records) <-> 'Adrenaline Allstars Blaze' (1 records) - 86.3% similar
#   'Golden Girls Oehh' (1 records) <-> 'Golden Girls Oep' (1 records) - 90.9% similar
#   'Elite All Stars' (3 records) <-> 'Elite All Starz' (4 records) - 93.3% similar
#   'Golden Stars' (1 records) <-> 'Gold Star' (1 records) - 85.7% similar
#   'The Vision Dance Center Allstars' (11 records) <-> 'The Vision Dance Center All Stars' (2 records) - 98.5% similar
#   'The Vision Dance Center Allstars' (11 records) <-> 'The Vision Dance Center - Senior Allstars' (2 records) - 87.7% similar
#   'Senior All Stars' (15 records) <-> 'Senior All Star Pom' (1 records) - 85.7% similar
#   'Meba Open Jazz Team' (1 records) <-> 'Meba Senior Jazz Team' (1 records) - 85.0% similar
#   'Foursis Dazzler Dance Team' (1 records) <-> 'Foursis Dazzlers Dance' (2 records) - 87.5% similar
#   'Sda - Elite All Starz - Open Kick' (1 records) <-> 'Sda - Elite All Starz - Open Pom' (1 records) - 89.2% similar
#   'Adrenaline Allstars - Rush Crew' (1 records) <-> 'Adrenaline Allstars - Thunder Crew' (1 records) - 86.2% similar
#   'Pittsburgh Poison All Stars - King Cobras' (1 records) <-> 'Pittsburgh Poison All Stars - Nyah' (1 records) - 85.3% similar
#   'Adrenaline Allstars Blaze' (1 records) <-> 'Adrenaline Allstars Joules' (1 records) - 86.3% similar
#   'Meba Open Lyrical Team' (1 records) <-> 'Meba Senior Lyrical Team' (1 records) - 87.0% similar
#   'Elite All Starz - Open Pom' (1 records) <-> 'Sda - Elite All Starz - Open Pom' (1 records) - 89.7% similar
#   'Elite All Starz - Open Pom' (1 records) <-> 'Elite All Starz Open Pom' (1 records) - 96.0% similar
#   'Sda - Elite All Starz - Open Pom' (1 records) <-> 'Elite All Starz Open Pom' (1 records) - 85.7% similar
#   'The Vision Dance Center All Stars' (2 records) <-> 'The Vision Dance Center - Senior Allstars' (2 records) - 86.5% similar
#   'Dancer’S Edge Studio – Senior Small' (1 records) <-> 'Dancer'S Edge Studio- Senior Small Jazz' (1 records) - 86.5% similar
#   'Dance Dynamics – Senior Contemporary' (1 records) <-> 'Dance Dynamics - Senior Contemporary' (2 records) - 97.2% similar
#   'Champion Legacy - Seniors' (1 records) <-> 'Champion Legacy - Ssj' (1 records) - 87.0% similar
#   'Dance Etc Inc- Senior Elite' (1 records) <-> 'Dance Etc Inc - Senior Elite Small' (1 records) - 88.5% similar
#   '5678! Dance Studio – Senior All Stars' (3 records) <-> '5678! Dance Studio - Senior All Stars' (3 records) - 97.3% similar
#   'Dancer'S Edge Studio - Senior Large Contemporary' (1 records) <-> 'Dancer'S Edge Studio - Senior Small Contemporary' (1 records) - 91.7% similar
#   'The Vision Dance Center - Senior Allstars' (2 records) <-> 'The Vision Dance Center Senior Small Jazz' (1 records) - 85.4% similar
#   'Mt Eden Ballet Academy - Slcl' (1 records) <-> 'Mt Eden Ballet Academy - Sscl' (1 records) - 96.6% similar
#   'Star Steppers - Stars Steppers Dance' (1 records) <-> 'Star Steppers - Star Steppers Dance' (1 records) - 98.6% similar
#   'Music City All Stars - Slcl' (1 records) <-> 'Music City All Stars - Slp' (1 records) - 94.3% similar
#   'Champion Legacy - Slcl' (1 records) <-> 'Champion Legacy - Slhh' (1 records) - 90.9% similar
#   'Champion Legacy - Slcl' (1 records) <-> 'Champion Legacy - Ssj' (1 records) - 88.4% similar
#   'Champion Legacy - Slcl' (1 records) <-> 'Champion Legacy - Slp' (1 records) - 93.0% similar
#   'Champion Legacy - Slcl' (1 records) <-> 'Champion Legacy - Schh' (1 records) - 90.9% similar
#   'Powerworx Dance - Team Radiant' (1 records) <-> 'Powerworx Dance Radiant' (1 records) - 86.8% similar
#   'South Coast Freestyle - Sscl' (1 records) <-> 'South Coast Freestyle - Ssj' (1 records) - 94.5% similar
#   'South Coast Freestyle - Sscl' (1 records) <-> 'South Coast Freestyle - Hand Clap' (1 records) - 85.2% similar
#   'Dancin' With Roxie' (2 records) <-> 'Dancin With Roxie' (2 records) - 97.1% similar
#   'Dollhouse Dance Factory - Hustle' (1 records) <-> 'Dollhouse Dance Factory - Hype' (1 records) - 90.3% similar
#   'Star Performance Centre – Senior Large All Girl' (1 records) <-> 'Star Performance Centre – Senior Large Jazz' (1 records) - 88.9% similar
#   'Star Performance Centre – Senior Large All Girl' (1 records) <-> 'Star Performance Centre – Senior Large Pom' (1 records) - 87.6% similar
#   'Pittsburgh Poison All Stars - Black Widows' (1 records) <-> 'Pittsburgh Poison - Black Widows' (2 records) - 86.5% similar
#   'Pittsburgh Poison All Stars - Black Widows' (1 records) <-> 'Pittsburgh Poison All Stars – Black Widows' (1 records) - 97.6% similar
#   'Pittsburgh Poison All Stars - Black Widows' (1 records) <-> 'Pittsburgh Poison All Stars Black Widows' (1 records) - 97.6% similar
#   'Champion Legacy - Slhh' (1 records) <-> 'Champion Legacy - Ssj' (1 records) - 88.4% similar
#   'Champion Legacy - Slhh' (1 records) <-> 'Champion Legacy - Slp' (1 records) - 93.0% similar
#   'Champion Legacy - Slhh' (1 records) <-> 'Champion Legacy - Schh' (1 records) - 95.5% similar
#   'Pittsburgh Poison - Black Widows' (2 records) <-> 'Pittsburgh Poison All Stars Black Widows' (1 records) - 86.1% similar
#   'Ultimate Allstars' (2 records) <-> 'Ulltimate All Stars' (1 records) - 94.4% similar
#   'Legendary Athletics - Slhh' (1 records) <-> 'Legendary Athletics - Sshh' (1 records) - 96.2% similar
#   'Pittsburgh Poison All Stars – Black Widows' (1 records) <-> 'Pittsburgh Poison All Stars Black Widows' (1 records) - 97.6% similar
#   'Premier Athletics - Northern Kentucky - Onyx' (1 records) <-> 'Premier Athletics - Northern Kentucky Mob' (1 records) - 91.8% similar
#   'Premier Athletics - Clayton - Scorpius' (1 records) <-> 'Premier Athletics Clayton - Scorpio' (1 records) - 93.2% similar
#   'Pittsburgh Pride All Stars – Ambush' (1 records) <-> 'Pittsburgh Pride All Stars - Ambush' (2 records) - 97.1% similar
#   'Pittsburgh Pride All Stars – Ambush' (1 records) <-> 'Pittsburgh Pride All Stars - Pulse' (1 records) - 87.0% similar
#   'Jordan Johnson Productions - Fierce Kids' (1 records) <-> 'Jordan Johnson Productions - Swagg Kids' (1 records) - 86.1% similar
#   'Jordan Johnson Productions - Fierce Kids' (1 records) <-> 'Jordan Johnosn Productions Fly Kids' (1 records) - 85.3% similar
#   'Legendary Athletics – Senior Elite' (1 records) <-> 'Legendary Athletics – Senior Coed Elite' (1 records) - 93.2% similar
#   'Pittsburgh Pride All Stars - Ambush' (2 records) <-> 'Pittsburgh Pride All Stars - Pulse' (1 records) - 89.9% similar
#   'Pittsburgh Poison All Stars – Nyah' (1 records) <-> 'Pittsburgh Poison All Stars - Nyah' (1 records) - 97.1% similar
#   'Pittsburgh Poison All Stars – Nyah' (1 records) <-> 'Pittsburgh Poison All Stars - Cyanide' (2 records) - 87.3% similar
#   'Pittsburgh Poison All Stars – Nyah' (1 records) <-> 'Pittsburgh Poison All Stars Cyanide' (1 records) - 87.0% similar
#   'Xtreme Dance - Sshh' (1 records) <-> 'Xtreme Dance - Slp' (1 records) - 86.5% similar
#   'Xtreme Dance - Sshh' (1 records) <-> 'Xtreme Dance - Ssp' (1 records) - 91.9% similar
#   'Strut Performing Arts – Senior Hip Hop' (1 records) <-> 'Strut Performing Arts – Senior Pom' (1 records) - 91.7% similar
#   'Imperial Athletics - Stellar' (2 records) <-> 'Imperial Athletics – Stellar' (1 records) - 96.4% similar
#   'Ultimate Allstars – Red Thunder' (1 records) <-> 'Ultimate Allstars - Red Thunder' (2 records) - 96.8% similar
#   'Strut Performing Arts - Sshh' (1 records) <-> 'Strut Performing Arts - Ssp' (1 records) - 94.5% similar
#   'Strut Performing Arts - Sshh' (1 records) <-> 'Strut Performing Arts - Sschh' (1 records) - 98.2% similar
#   'Pittsburgh Poison All Stars - Nyah' (1 records) <-> 'Pittsburgh Poison All Stars - Cyanide' (2 records) - 90.1% similar
#   'Pittsburgh Poison All Stars - Nyah' (1 records) <-> 'Pittsburgh Poison All Stars Cyanide' (1 records) - 87.0% similar
#   'Peak Athletics - Sabres' (1 records) <-> 'Peak Athletics – Sabers' (1 records) - 91.3% similar
#   'Peak Athletics - Sabres' (1 records) <-> 'Peak Athletics Sabers' (1 records) - 90.9% similar
#   'Peak Athletics - Sabres' (1 records) <-> 'Peak Athletics- Sabers' (1 records) - 93.3% similar
#   'Champion Legacy – Small Senior Hip Hop' (1 records) <-> 'Champion Legacy – Senior Coed Hip Hop' (1 records) - 85.3% similar
#   'Dancers Edge - Sr Silver Jazz' (1 records) <-> 'Dancers Edge - Sr Blue Jazz' (1 records) - 89.3% similar
#   'Dane Dynamics' (1 records) <-> 'Dance Dynamixs' (1 records) - 88.9% similar
#   'Dane Dynamics' (1 records) <-> 'Dance Dynamic' (1 records) - 92.3% similar
#   'Dancer’S Edge Studio – Senior Large Jazz' (1 records) <-> 'Dancer’S Edge Studio – Senior Large Pom' (1 records) - 91.1% similar
#   'Dance Dynamics - Slj' (1 records) <-> 'Dance Dynamics - Ssj' (1 records) - 95.0% similar
#   'Star Performance Centre - Slj' (1 records) <-> 'Star Performance Centre - Slp' (1 records) - 96.6% similar
#   'Star Performance Centre - Slj' (1 records) <-> 'Star Performance Centre - Schh' (1 records) - 91.5% similar
#   'Star Performance Centre – Senior Large Jazz' (1 records) <-> 'Star Performance Centre – Senior Large Pom' (1 records) - 91.8% similar
#   'Dance Mania - Ssj' (1 records) <-> 'Dance Mania - Ssp' (1 records) - 94.1% similar
#   'Champion Legacy - Ssj' (1 records) <-> 'Champion Legacy - Slp' (1 records) - 90.5% similar
#   'Champion Legacy - Ssj' (1 records) <-> 'Champion Legacy - Schh' (1 records) - 88.4% similar
#   'South Coast Freestyle- Diana' (1 records) <-> 'South Coast Freestyle - Hand Clap' (1 records) - 85.2% similar
#   '5-6-7-8 Senior All Stars' (1 records) <-> '5678! Senior All Stars' (6 records) - 91.3% similar
#   'The Power Of Dance - Polaris' (3 records) <-> 'Power Of Dance – Polaris' (1 records) - 88.5% similar
#   'Power Of Dance, Llc - Polaris' (1 records) <-> 'Power Of Dance – Polaris' (1 records) - 86.8% similar
#   'Champion Legacy - Slp' (1 records) <-> 'Champion Legacy - Schh' (1 records) - 88.4% similar
#   'Star Performance Centre – Senior Large Pom' (1 records) <-> 'Star Performance Centre – Senior Small Pom' (1 records) - 90.5% similar
#   'Star Performance Centre – Senior Large Pom' (1 records) <-> 'Star Performance Centre – Senior Large Coed Hip Hop' (1 records) - 88.2% similar
#   'Energizers - Slp' (1 records) <-> 'Energizers - Ssp' (1 records) - 93.8% similar
#   'Xtreme Dance - Slp' (1 records) <-> 'Xtreme Dance - Ssp' (1 records) - 94.4% similar
#   'Star Performance Centre - Slp' (1 records) <-> 'Star Performance Centre - Schh' (1 records) - 91.5% similar
#   'Dance Dynamixs' (1 records) <-> 'Dance Dynamic' (1 records) - 88.9% similar
#   'Strut Performing Arts - Ssp' (1 records) <-> 'Strut Performing Arts - Sschh' (1 records) - 92.9% similar
#   'Peak Athletics – Sabers' (1 records) <-> 'Peak Athletics Sabers' (1 records) - 95.5% similar
#   'Peak Athletics – Sabers' (1 records) <-> 'Peak Athletics- Sabers' (1 records) - 93.3% similar
#   'Peak Athletics Sabers' (1 records) <-> 'Peak Athletics- Sabers' (1 records) - 97.7% similar
#   'Pittsburgh Poison All Stars - Cyanide' (2 records) <-> 'Pittsburgh Poison All Stars Cyanide' (1 records) - 97.2% similar
#   'Adrenaline All Stars - Thunder Crew' (1 records) <-> 'Adrenaline Allstars - Thunder Crew' (1 records) - 98.6% similar
#   'Pittsburgh Poison - Dart Frogs' (2 records) <-> 'Pittsburgh Poison All Stars Dart Frogs' (1 records) - 85.3% similar
#   'Midwest Cheer Elite Cleveland - Black Ice Krew' (1 records) <-> 'Midwest Cheer Elite - Cleveland - Black Ice Crew' (1 records) - 95.7% similar
#   'Midwest Cheer Elite Cleveland - Black Ice Krew' (1 records) <-> 'Midwest Cheer Elite Cleveland – Black Ice Krew' (1 records) - 97.8% similar
#   'Midwest Cheer Elite - Cleveland - Black Ice Crew' (1 records) <-> 'Midwest Cheer Elite Cleveland – Black Ice Krew' (1 records) - 93.6% similar
#   'Dance Mania Senior Jazz Large' (2 records) <-> 'Dance Mania Senior Pom Large' (1 records) - 87.7% similar
#   'Senior Large Coed Hip Hop' (4 records) <-> 'Senior Large Hip Hop' (5 records) - 88.9% similar
#   'The Vision Dance Center Senior Large Lyrical' (2 records) <-> 'The Vision Dance Center Senior Small Lyrical' (1 records) - 90.9% similar
#   'Senior Large Contemporary' (1 records) <-> 'Senior Large Contemporary/Lyrical' (2 records) - 86.2% similar
#   'Senior Contemporary/Lyrical - Large' (2 records) <-> 'Senior - Contemporary/Lyrical - Small' (2 records) - 86.1% similar
#   'Senior Contemporary/Lyrical - Large' (2 records) <-> 'Senior Contemporary/Lyrical Small' (1 records) - 85.3% similar
#   'Senior Contemporary/Lyrical - Large' (2 records) <-> 'Senior Contemporary/Lyrical - Small' (2 records) - 88.6% similar
#   'Senior Large Lyrical' (3 records) <-> 'Dmn - Senior Large Lyrical' (1 records) - 87.0% similar
#   'Dancin' With Roxie Prestige' (4 records) <-> 'Dancin With Roxie Prestige' (8 records) - 98.1% similar
#   'Senior Large Contemporary/Lyrical' (2 records) <-> 'Senior Small Contemporary/Lyrical' (1 records) - 87.9% similar
#   'Senior Hip Hop - Large' (1 records) <-> 'Senior Pom - Large' (1 records) - 85.0% similar
#   'Senior All Star Large Jazz' (1 records) <-> 'Senior All Star Large Pom' (1 records) - 86.3% similar
#   'Senior All Star Large Jazz' (1 records) <-> 'Senior All Star Jazz' (1 records) - 87.0% similar
#   'Senior Pom Large' (2 records) <-> 'Senior Pom - Large' (1 records) - 94.1% similar
#   'Dance Mania Senior Pom Large' (1 records) <-> 'Dance Mania Senior Pom Small' (1 records) - 85.7% similar
#   'Senior All Star Large Pom' (1 records) <-> 'Senior All Star Pom' (1 records) - 86.4% similar
#   'Senior Small Coed Hip Hop' (2 records) <-> 'Senior Small Hip Hop' (7 records) - 88.9% similar
#   'The Vision Dance Center Senior Small Lyrical' (1 records) <-> 'The Vision Dance Center Senior Small Jazz' (1 records) - 89.4% similar
#   'Senior Small Contemporary' (2 records) <-> 'Senior Small Contemporary/Lyrical' (1 records) - 86.2% similar
#   'Senior - Contemporary/Lyrical - Small' (2 records) <-> 'Senior Contemporary/Lyrical Small' (1 records) - 94.3% similar
#   'Senior - Contemporary/Lyrical - Small' (2 records) <-> 'Senior Contemporary/Lyrical - Small' (2 records) - 97.2% similar
#   'Senior Contemporary/Lyrical Small' (1 records) <-> 'Senior Contemporary/Lyrical - Small' (2 records) - 97.1% similar
#   'Innovate Dance Studio Senior Lyrical' (1 records) <-> 'Innovate Dance Studio Senior Pom' (1 records) - 85.3% similar
#   'Senior Small Hip Hop' (7 records) <-> 'Dmn - Senior Small Hip Hop' (1 records) - 87.0% similar
#   'High Voltage' (2 records) <-> 'Mde High Voltage' (1 records) - 85.7% similar
#   'Senior Hip Hop - Small' (1 records) <-> 'Senior Pom - Small' (5 records) - 85.0% similar
#   'Senior Jazz Small' (3 records) <-> 'Senior Jazz - Small' (3 records) - 94.4% similar
#   'Senior Pom Small' (1 records) <-> 'Senior Pom - Small' (5 records) - 94.1% similar
#
# Studio names - Original unique: 505, After cleaning: 499
# Team names - Original unique: 1235, After cleaning: 1217
#
# Examples of cleaned studio names:
#   'Dancer's Edge Studio' -> 'Dancer'S Edge Studio'
#   'ABE Dance Promotion' -> 'Abe Dance Promotion'
#   'SPG Dance Project' -> 'Spg Dance Project'
#   'KLD X-treme All Star Cheerleaders' -> 'Kld X-Treme All Star Cheerleaders'
#   'MC Planet Dance' -> 'Mc Planet Dance'
#   'The Legacy - So What ' -> 'The Legacy - So What'
#   'Champion Dance & Cheer allstars' -> 'Champion Dance & Cheer Allstars'
#   'Evolution of Dance' -> 'Evolution Of Dance'
#   'ZACS Allstars' -> 'Zacs Allstars'
#   'Colegio Palermo de Medellin' -> 'Colegio Palermo De Medellin'
#
# Examples of cleaned team names:
#   'Dancer's Edge' -> 'Dancer'S Edge'
#   'Dancer's Edge Studio' -> 'Dancer'S Edge Studio'
#   'Dancer's Edge Studio- Junior Lyrical' -> 'Dancer'S Edge Studio- Junior Lyrical'
#   'ABE Dance Promotion- Blue Star' -> 'Abe Dance Promotion- Blue Star'
#   'SPG Dance Project - H Beat Beans' -> 'Spg Dance Project - H Beat Beans'
#   'KLD All Stars - Elite Reign' -> 'Kld All Stars - Elite Reign'
#   'MC Planet Dance' -> 'Mc Planet Dance'
#   'Champion Dance and Cheer All Stars' -> 'Champion Dance And Cheer All Stars'
#   'Evolution of Dance' -> 'Evolution Of Dance'
#   'ZACS Allstars' -> 'Zacs Allstars'

# %% [markdown]
# ### Country

# %%
# Fill Country with 'USA' when Division is 'Senior'
df.loc[df['Division'] == 'Senior', 'Country'] = 'USA'

# Show the result
senior_count = len(df[df['Division'] == 'Senior'])
print(f"Updated {senior_count} Senior division records with Country = 'USA'")

# Save the updated dataframe
df.to_csv('dance_worlds_data_20251004_221418.csv', index=False)
# Out:
# Updated 827 Senior division records with Country = 'USA'

# %%
# Show current state
print("Current country distribution:")
print(df['Country'].value_counts())
print(f"\nUnknown countries: {len(df[df['Country'] == 'Unknown'])}")

# For each studio, find the most common country (excluding 'Unknown')
def get_studio_country(studio_name):
    # Get all records for this studio
    studio_records = df[df['Studio_Name_Clean'] == studio_name]
    
    # Get countries that are not 'Unknown'
    known_countries = studio_records[studio_records['Country'] != 'Unknown']['Country']
    
    if len(known_countries) > 0:
        # Return the most common known country
        return known_countries.mode()[0]
    else:
        return 'Unknown'

# Create a mapping of studio to country
studio_country_map = {}
for studio in df['Studio_Name_Clean'].unique():
    studio_country_map[studio] = get_studio_country(studio)

# Fill in missing/unknown countries based on studio
df['Country_Updated'] = df.apply(
    lambda row: studio_country_map[row['Studio_Name_Clean']] 
    if row['Country'] == 'Unknown' 
    else row['Country'], 
    axis=1
)

# Show what changed
changes = df[df['Country'] != df['Country_Updated']]
print(f"\nUpdated {len(changes)} records based on studio country:")

if len(changes) > 0:
    # Show examples
    print("\nExamples of updates:")
    sample = changes[['Studio_Name_Clean', 'Country', 'Country_Updated']].drop_duplicates().head(10)
    for _, row in sample.iterrows():
        print(f"  {row['Studio_Name_Clean']}: '{row['Country']}' -> '{row['Country_Updated']}'")

# Replace the old Country column
df['Country'] = df['Country_Updated']
df = df.drop(columns=['Country_Updated'])

# Show new distribution
print("\nNew country distribution:")
print(df['Country'].value_counts())
print(f"\nRemaining unknown countries: {len(df[df['Country'] == 'Unknown'])}")

# Save the updated dataframe
df.to_csv('dance_worlds_data_20251004_221418.csv', index=False)
# Out:
# Current country distribution:
# Country
# USA            1181
# Unknown         236
# England          84
# Mexico           76
# Scotland         69
# Japan            64
# Australia        50
# Colombia         41
# Ecuador          40
# Chile            23
# Wales            20
# France           14
# Puerto Rico      11
# Canada            8
# Germany           8
# Ukraine           8
# Netherlands       6
# Poland            3
# Sweden            3
# Italy             2
# Monaco            2
# Philippines       1
# New Zealand       1
# Russia            1
# Taiwan            1
# Name: count, dtype: int64
#
# Unknown countries: 236
#
# Updated 0 records based on studio country:
#
# New country distribution:
# Country
# USA            1181
# Unknown         236
# England          84
# Mexico           76
# Scotland         69
# Japan            64
# Australia        50
# Colombia         41
# Ecuador          40
# Chile            23
# Wales            20
# France           14
# Puerto Rico      11
# Canada            8
# Germany           8
# Ukraine           8
# Netherlands       6
# Poland            3
# Sweden            3
# Italy             2
# Monaco            2
# Philippines       1
# New Zealand       1
# Russia            1
# Taiwan            1
# Name: count, dtype: int64
#
# Remaining unknown countries: 236

# %%
# Unkown countries list 
unknown_studios = df[df['Country'] == 'Unknown'][['Studio_Name_Clean']].drop_duplicates().sort_values('Studio_Name_Clean')
unknown_studios['Country'] = ''  

# Save to CSV for manual research
unknown_studios.to_csv('studios_to_research.csv', index=False)

# %%
# Load your research
studio_countries = pd.read_csv('studios_to_research_1.csv')

# Load the main data
df = pd.read_csv('dance_worlds_data_20251004_221418.csv')

# Create a mapping dictionary
studio_country_map = dict(zip(studio_countries['Studio_Name_Clean'], studio_countries['Country']))

# Update countries based on your research
df['Country'] = df.apply(
    lambda row: studio_country_map.get(row['Studio_Name_Clean'], row['Country']) 
    if row['Country'] == 'Unknown' and row['Studio_Name_Clean'] in studio_country_map 
    else row['Country'],
    axis=1
)

# Show results
print(f"Updated countries from research")
print(f"Remaining unknown countries: {len(df[df['Country'] == 'Unknown'])}")
print("Country distribution:")
print(df['Country'].value_counts())

# Save updated data
df.to_csv('dance_worlds_data_20251004_221418.csv', index=False)
# Out:
# Updated countries from research
# Remaining unknown countries: 2
# Country distribution:
# Country
# USA               1255
# England            104
# Mexico              92
# Scotland            75
# Japan               71
# Australia           64
# Colombia            54
# Ecuador             47
# Chile               27
# Wales               20
# Germany             18
# China               16
# France              14
# Puerto Rico         11
# Ukraine             10
# Norway              10
# Netherlands          8
# Canada               8
# Poland               6
# Taiwan               5
# Sweden               4
# Brazil               4
# Italy                4
# Guatemala            3
# Switzerland          3
# Columbia             2
# South Korea          2
# Unknown              2
# Denmark              2
# Monaco               2
# Czech Republic       1
# Croatia              1
# El Salvador          1
# Philippines          1
# New Zealand          1
# Costa Rica           1
# Slovenia             1
# Russia               1
# Israel               1
# Belguim              1
# Name: count, dtype: int64

# %% [markdown]
# ### Data Preperation

# %%
#Delete old columns
columns_to_delete = ['Category', 'Category_Clean', 'Studio_Name', 'Team_Name']
df = df.drop(columns=columns_to_delete)

# Show remaining columns
print("Remaining columns:")
for col in df.columns:
    print(f"  {col}")

# Save the updated dataframe
df.to_csv('dance_worlds_data_20251004_221418.csv', index=False)
# Out:
# Remaining columns:
#   Year
#   Rank
#   Country
#   Dance_Type
#   Category_Standardized
#   Division
#   Studio_Name_Clean
#   Team_Name_Clean

# %%
# Standardise column names
df = df.rename(columns={
    'Studio_Name_Clean': 'Studio_Name',
    'Team_Name_Clean': 'Team_Name',
    'Category_Standardized': 'Category'
})

# Drop Category_Clean since we have Category
if 'Category_Clean' in df.columns:
    df = df.drop(columns=['Category_Clean'])

# %% [markdown]
# ### Feature engineering

# %%
df['Is_Champion'] = (df['Rank'] == 1).astype(int)
df['Is_Podium'] = (df['Rank'] <= 3).astype(int)
df['Is_Top_10'] = (df['Rank'] <= 10).astype(int)

# %%
# Extract team size from category if present
def extract_team_size(category):
    if pd.isna(category):
        return 'Unknown'
    category_str = str(category).lower()
    if 'small' in category_str:
        return 'Small'
    elif 'large' in category_str:
        return 'Large'
    else:
        return 'Standard'

df['Team_Size'] = df['Category'].apply(extract_team_size)

# %%
# Extract if team is Coed
def is_coed(category):
    if pd.isna(category):
        return 'No'
    return 'Yes' if 'Coed' in str(category) else 'No'

df['Is_Coed'] = df['Category'].apply(is_coed)

# %% [markdown]
# ### Data Checks

# %%
# Check data quality
print("\nData quality check:")
print(f"Missing values by column:")
print(df.isnull().sum())

print(f"\nDuplicate rows: {df.duplicated().sum()}")

# Ensure correct data types
df['Year'] = df['Year'].astype(int)
df['Rank'] = df['Rank'].astype(int)
# Out:
# Data quality check:
# Missing values by column:
# Year           0
# Rank           0
# Country        0
# Dance_Type     0
# Category       0
# Division       0
# Studio_Name    0
# Team_Name      2
# Is_Champion    0
# Is_Podium      0
# Is_Top_10      0
# Team_Size      0
# Is_Coed        0
# dtype: int64
#
# Duplicate rows: 0

# %%
# 7. Sort by Year and Rank for better organisation
df = df.sort_values(['Year', 'Division', 'Category', 'Rank']).reset_index(drop=True)

# 8. Reorder columns for logical flow
column_order = [
    'Year',
    'Division',
    'Category',
    'Dance_Type',
    'Team_Size',
    'Is_Coed',
    'Rank',
    'Is_Champion',
    'Is_Podium',
    'Is_Top_10',
    'Studio_Name',
    'Team_Name',
    'Country'
]

df = df[column_order]

# %%
# Show final summary
print("\nFinal dataset summary:")
print(f"Total records: {len(df)}")
print(f"Years covered: {df['Year'].min()} - {df['Year'].max()}")
print(f"Divisions: {df['Division'].unique()}")
print(f"Countries: {df['Country'].nunique()}")
print(f"Studios: {df['Studio_Name'].nunique()}")

print("\nColumn list:")
for i, col in enumerate(df.columns, 1):
    print(f"  {i}. {col}")

print("\nSample data:")
print(df.head(10))

# Save final Power BI ready dataset
df.to_csv('dance_worlds_clean_data.csv', index=False)
# Out:
# Final dataset summary:
# Total records: 1953
# Years covered: 2015 - 2025
# Divisions: ['Junior' 'Open' 'Senior']
# Countries: 40
# Studios: 499
#
# Column list:
#   1. Year
#   2. Division
#   3. Category
#   4. Dance_Type
#   5. Team_Size
#   6. Is_Coed
#   7. Rank
#   8. Is_Champion
#   9. Is_Podium
#   10. Is_Top_10
#   11. Studio_Name
#   12. Team_Name
#   13. Country
#
# Sample data:
#    Year Division      Category    Dance_Type Team_Size Is_Coed  Rank  \
# 0  2015   Junior  Junior Dance  Junior Dance  Standard      No     1
# 1  2015   Junior  Junior Dance  Junior Dance  Standard      No     2
# 2  2015   Junior  Junior Dance  Junior Dance  Standard      No     3
# 3  2015   Junior  Junior Dance  Junior Dance  Standard      No     4
# 4  2015   Junior  Junior Dance  Junior Dance  Standard      No     5
# 5  2015   Junior  Junior Dance  Junior Dance  Standard      No     6
# 6  2015   Junior  Junior Dance  Junior Dance  Standard      No     7
# 7  2015   Junior  Junior Dance  Junior Dance  Standard      No     8
# 8  2015   Junior  Junior Dance  Junior Dance  Standard      No     9
# 9  2015   Junior  Junior Dance  Junior Dance  Standard      No    10
#
#    Is_Champion  Is_Podium  Is_Top_10                       Studio_Name  \
# 0            1          1          1              Dancer'S Edge Studio
# 1            0          1          1                            C*Star
# 2            0          1          1                Dancin Bluebonnets
# 3            0          0          1             South Coast Freestyle
# 4            0          0          1                      Golden Hawks
# 5            0          0          1          Jexer Fitness Cuib Omiya
# 6            0          0          1  Centro Artistico Yesenea Mendoza
# 7            0          0          1                           Uniques
# 8            0          0          1              The Legacy - So What
# 9            0          0          1                Evolution Of Dance
#
#                                       Team_Name      Country
# 0                                 Dancer'S Edge          USA
# 1                                  C*Star Artis        Japan
# 2               Dancin' Bluebonnets - Open Jazz          USA
# 3                         South Coast Freestyle          USA
# 4                               Golden Hawks Jr        Japan
# 5               Jexer Fitness Cuib Omiya Zingys        Japan
# 6  Centro Artistico Yesenea Mendoza - I Believe      Ecuador
# 7                               Uniques Academy     Colombia
# 8                          The Legacy - So What  Netherlands
# 9                            Evolution Of Dance          USA
